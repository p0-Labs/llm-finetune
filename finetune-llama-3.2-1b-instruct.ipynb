# %%
# for colab
# !huggingface-cli login
# !huggingface-cli download meta-llama/Llama-3.2-1B-Instruct --exclude "original/*" --local-dir meta-llama/Llama-3.2-1B-Instruct
# !pip install -q datasets trl torch transformers peft bitsandbytes
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `colab-token` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `colab-token`
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]Downloading 'special_tokens_map.json' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.02ee80b6196926a5ad790a004d9efd6ab1ba6542.incomplete'
# Downloading '.gitattributes' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# Downloading 'model.safetensors' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.1ff795ff6a07e6a68085d206fb84417da2f083f68391c2843cd2b8ac6df8538f.incomplete'
# Downloading 'config.json' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.3e3aaf51a035cb5092d9f6827a0dc074657ba88c.incomplete'
# Downloading 'README.md' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.b3c62ef6190712fb3e31af1628f0b85706fc4ba8.incomplete'
#
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 2.75MB/s]
# Downloading 'LICENSE.txt' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/cyBuwAu93UXke23CJCWORBYR70A=.085b47c1575cb889b7024030e60b78f54f0b8c9e.incomplete'
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/special_tokens_map.json
# Downloading 'USE_POLICY.md' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/UcPfAI5B08awK9_TiALuc0iOThI=.ac3c5f21b9779e3da0677d6d3c587778fe3a331e.incomplete'
# Downloading 'generation_config.json' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.75ae08310d6d23df373ee2644b497192b3cce6d8.incomplete'
#
# config.json: 100% 877/877 [00:00<00:00, 9.63MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/config.json
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 18.1MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/.gitattributes
# Fetching 10 files:  10% 1/10 [00:00<00:01,  6.55it/s]
# README.md:   0% 0.00/41.7k [00:00<?, ?B/s]Downloading 'tokenizer.json' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.5cc5f00a5b203e90a27a3bd60d1ec393b07971e8.incomplete'
#
#
# USE_POLICY.md: 100% 6.02k/6.02k [00:00<00:00, 48.1MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/USE_POLICY.md
#
#
# LICENSE.txt: 100% 7.71k/7.71k [00:00<00:00, 34.7MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/LICENSE.txt
# README.md: 100% 41.7k/41.7k [00:00<00:00, 3.98MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/README.md
#
# generation_config.json: 100% 189/189 [00:00<00:00, 2.43MB/s]
#
# model.safetensors:   0% 0.00/2.47G [00:00<?, ?B/s]Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/generation_config.json
# Downloading 'tokenizer_config.json' to 'meta-llama/Llama-3.2-1B-Instruct/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.4ff488a165e900e5129cda7c20ab32d568d2a475.incomplete'
#
#
# tokenizer.json:   0% 0.00/9.09M [00:00<?, ?B/s]
#
#
# tokenizer_config.json: 100% 54.5k/54.5k [00:00<00:00, 5.20MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/tokenizer_config.json
#
# model.safetensors:   0% 10.5M/2.47G [00:00<01:05, 37.8MB/s]
#
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 24.7MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/tokenizer.json
#
# model.safetensors:   1% 21.0M/2.47G [00:00<01:00, 40.4MB/s]
# model.safetensors:   1% 31.5M/2.47G [00:00<00:58, 41.4MB/s]
# model.safetensors:   2% 41.9M/2.47G [00:01<00:57, 42.2MB/s]
# model.safetensors:   2% 52.4M/2.47G [00:01<00:57, 42.3MB/s]
# model.safetensors:   3% 62.9M/2.47G [00:01<00:56, 42.3MB/s]
# model.safetensors:   3% 73.4M/2.47G [00:01<00:56, 42.6MB/s]
# model.safetensors:   3% 83.9M/2.47G [00:01<00:56, 42.5MB/s]
# model.safetensors:   4% 94.4M/2.47G [00:02<00:56, 42.4MB/s]
# model.safetensors:   4% 105M/2.47G [00:02<00:56, 42.2MB/s]
# model.safetensors:   5% 115M/2.47G [00:02<00:55, 42.3MB/s]
# model.safetensors:   5% 126M/2.47G [00:02<00:55, 42.5MB/s]
# model.safetensors:   6% 136M/2.47G [00:03<00:54, 42.7MB/s]
# model.safetensors:   6% 147M/2.47G [00:03<00:54, 42.9MB/s]
# model.safetensors:   6% 157M/2.47G [00:03<00:54, 42.9MB/s]
# model.safetensors:   7% 168M/2.47G [00:03<00:53, 42.9MB/s]
# model.safetensors:   7% 178M/2.47G [00:04<00:53, 42.9MB/s]
# model.safetensors:   8% 189M/2.47G [00:04<00:53, 42.9MB/s]
# model.safetensors:   8% 199M/2.47G [00:04<00:52, 42.9MB/s]
# model.safetensors:   8% 210M/2.47G [00:04<00:52, 42.7MB/s]
# model.safetensors:   9% 220M/2.47G [00:05<00:52, 42.9MB/s]
# model.safetensors:   9% 231M/2.47G [00:05<00:52, 42.8MB/s]
# model.safetensors:  10% 241M/2.47G [00:05<00:52, 42.6MB/s]
# model.safetensors:  10% 252M/2.47G [00:05<00:51, 42.8MB/s]
# model.safetensors:  11% 262M/2.47G [00:06<00:51, 42.7MB/s]
# model.safetensors:  11% 273M/2.47G [00:06<00:51, 42.7MB/s]
# model.safetensors:  11% 283M/2.47G [00:06<00:51, 42.6MB/s]
# model.safetensors:  12% 294M/2.47G [00:06<00:51, 42.2MB/s]
# model.safetensors:  12% 304M/2.47G [00:07<00:51, 42.3MB/s]
# model.safetensors:  13% 315M/2.47G [00:07<00:50, 42.4MB/s]
# model.safetensors:  13% 325M/2.47G [00:07<00:50, 42.6MB/s]
# model.safetensors:  14% 336M/2.47G [00:07<00:49, 42.7MB/s]
# model.safetensors:  14% 346M/2.47G [00:08<00:49, 42.7MB/s]
# model.safetensors:  14% 357M/2.47G [00:08<00:49, 42.7MB/s]
# model.safetensors:  15% 367M/2.47G [00:08<00:49, 42.9MB/s]
# model.safetensors:  15% 377M/2.47G [00:08<00:48, 42.9MB/s]
# model.safetensors:  16% 388M/2.47G [00:09<00:48, 42.9MB/s]
# model.safetensors:  16% 398M/2.47G [00:09<00:48, 42.8MB/s]
# model.safetensors:  17% 409M/2.47G [00:09<00:48, 42.8MB/s]
# model.safetensors:  17% 419M/2.47G [00:09<00:47, 42.9MB/s]
# model.safetensors:  17% 430M/2.47G [00:10<00:47, 42.9MB/s]
# model.safetensors:  18% 440M/2.47G [00:10<00:47, 42.8MB/s]
# model.safetensors:  18% 451M/2.47G [00:10<00:47, 42.9MB/s]
# model.safetensors:  19% 461M/2.47G [00:10<00:47, 42.7MB/s]
# model.safetensors:  19% 472M/2.47G [00:11<00:46, 42.6MB/s]
# model.safetensors:  20% 482M/2.47G [00:11<00:46, 42.7MB/s]
# model.safetensors:  20% 493M/2.47G [00:11<00:46, 42.7MB/s]
# model.safetensors:  20% 503M/2.47G [00:11<00:46, 42.5MB/s]
# model.safetensors:  21% 514M/2.47G [00:12<00:45, 42.6MB/s]
# model.safetensors:  21% 524M/2.47G [00:12<00:45, 42.7MB/s]
# model.safetensors:  22% 535M/2.47G [00:12<00:45, 42.8MB/s]
# model.safetensors:  22% 545M/2.47G [00:12<00:45, 42.7MB/s]
# model.safetensors:  22% 556M/2.47G [00:13<00:44, 42.7MB/s]
# model.safetensors:  23% 566M/2.47G [00:13<00:44, 42.8MB/s]
# model.safetensors:  23% 577M/2.47G [00:13<00:44, 42.7MB/s]
# model.safetensors:  24% 587M/2.47G [00:13<00:44, 42.8MB/s]
# model.safetensors:  24% 598M/2.47G [00:14<00:43, 42.8MB/s]
# model.safetensors:  25% 608M/2.47G [00:14<00:43, 42.7MB/s]
# model.safetensors:  25% 619M/2.47G [00:14<00:43, 42.5MB/s]
# model.safetensors:  25% 629M/2.47G [00:14<00:53, 34.2MB/s]
# model.safetensors:  26% 640M/2.47G [00:15<00:46, 39.1MB/s]
# model.safetensors:  26% 650M/2.47G [00:15<00:45, 40.1MB/s]
# model.safetensors:  27% 661M/2.47G [00:15<00:44, 40.9MB/s]
# model.safetensors:  27% 671M/2.47G [00:15<00:43, 41.4MB/s]
# model.safetensors:  28% 682M/2.47G [00:16<00:42, 42.0MB/s]
# model.safetensors:  28% 692M/2.47G [00:16<00:42, 42.2MB/s]
# model.safetensors:  28% 703M/2.47G [00:16<00:41, 42.4MB/s]
# model.safetensors:  29% 713M/2.47G [00:16<00:41, 42.4MB/s]
# model.safetensors:  29% 724M/2.47G [00:17<00:41, 42.4MB/s]
# model.safetensors:  30% 734M/2.47G [00:17<00:41, 42.2MB/s]
# model.safetensors:  30% 744M/2.47G [00:17<00:40, 42.4MB/s]
# model.safetensors:  31% 755M/2.47G [00:17<00:40, 42.4MB/s]
# model.safetensors:  31% 765M/2.47G [00:18<00:40, 42.5MB/s]
# model.safetensors:  31% 776M/2.47G [00:18<00:39, 42.7MB/s]
# model.safetensors:  32% 786M/2.47G [00:18<00:39, 42.3MB/s]
# model.safetensors:  32% 797M/2.47G [00:18<00:39, 42.5MB/s]
# model.safetensors:  33% 807M/2.47G [00:19<00:39, 42.5MB/s]
# model.safetensors:  33% 818M/2.47G [00:19<00:38, 42.7MB/s]
# model.safetensors:  34% 828M/2.47G [00:19<00:38, 42.7MB/s]
# model.safetensors:  34% 839M/2.47G [00:19<00:38, 42.8MB/s]
# model.safetensors:  34% 849M/2.47G [00:20<00:37, 42.9MB/s]
# model.safetensors:  35% 860M/2.47G [00:20<00:37, 42.8MB/s]
# model.safetensors:  35% 870M/2.47G [00:20<00:37, 42.9MB/s]
# model.safetensors:  36% 881M/2.47G [00:20<00:37, 42.7MB/s]
# model.safetensors:  36% 891M/2.47G [00:21<00:36, 42.8MB/s]
# model.safetensors:  36% 902M/2.47G [00:21<00:36, 42.6MB/s]
# model.safetensors:  37% 912M/2.47G [00:21<00:36, 42.7MB/s]
# model.safetensors:  37% 923M/2.47G [00:21<00:36, 42.4MB/s]
# model.safetensors:  38% 933M/2.47G [00:22<00:36, 42.6MB/s]
# model.safetensors:  38% 944M/2.47G [00:22<00:35, 42.5MB/s]
# model.safetensors:  39% 954M/2.47G [00:22<00:35, 42.2MB/s]
# model.safetensors:  39% 965M/2.47G [00:22<00:35, 42.4MB/s]
# model.safetensors:  39% 975M/2.47G [00:23<00:35, 42.6MB/s]
# model.safetensors:  40% 986M/2.47G [00:23<00:34, 42.6MB/s]
# model.safetensors:  40% 996M/2.47G [00:23<00:34, 42.7MB/s]
# model.safetensors:  41% 1.01G/2.47G [00:23<00:34, 42.7MB/s]
# model.safetensors:  41% 1.02G/2.47G [00:24<00:34, 42.5MB/s]
# model.safetensors:  42% 1.03G/2.47G [00:24<00:33, 42.7MB/s]
# model.safetensors:  42% 1.04G/2.47G [00:24<00:33, 42.7MB/s]
# model.safetensors:  42% 1.05G/2.47G [00:24<00:33, 42.6MB/s]
# model.safetensors:  43% 1.06G/2.47G [00:25<00:41, 33.8MB/s]
# model.safetensors:  44% 1.08G/2.47G [00:25<00:30, 45.4MB/s]
# model.safetensors:  44% 1.09G/2.47G [00:25<00:30, 44.7MB/s]
# model.safetensors:  45% 1.10G/2.47G [00:25<00:31, 44.0MB/s]
# model.safetensors:  45% 1.11G/2.47G [00:26<00:31, 43.5MB/s]
# model.safetensors:  45% 1.12G/2.47G [00:26<00:31, 43.3MB/s]
# model.safetensors:  46% 1.13G/2.47G [00:26<00:30, 43.2MB/s]
# model.safetensors:  46% 1.14G/2.47G [00:26<00:30, 43.0MB/s]
# model.safetensors:  47% 1.15G/2.47G [00:27<00:30, 42.6MB/s]
# model.safetensors:  47% 1.16G/2.47G [00:27<00:30, 42.5MB/s]
# model.safetensors:  48% 1.17G/2.47G [00:27<00:30, 42.4MB/s]
# model.safetensors:  48% 1.18G/2.47G [00:27<00:30, 42.6MB/s]
# model.safetensors:  48% 1.20G/2.47G [00:28<00:29, 42.8MB/s]
# model.safetensors:  49% 1.21G/2.47G [00:28<00:29, 42.7MB/s]
# model.safetensors:  49% 1.22G/2.47G [00:28<00:29, 42.7MB/s]
# model.safetensors:  50% 1.23G/2.47G [00:28<00:29, 42.6MB/s]
# model.safetensors:  50% 1.24G/2.47G [00:29<00:28, 42.6MB/s]
# model.safetensors:  50% 1.25G/2.47G [00:29<00:28, 42.7MB/s]
# model.safetensors:  51% 1.26G/2.47G [00:29<00:28, 42.7MB/s]
# model.safetensors:  51% 1.27G/2.47G [00:29<00:28, 42.8MB/s]
# model.safetensors:  52% 1.28G/2.47G [00:30<00:27, 42.7MB/s]
# model.safetensors:  52% 1.29G/2.47G [00:30<00:27, 42.6MB/s]
# model.safetensors:  53% 1.30G/2.47G [00:30<00:27, 42.5MB/s]
# model.safetensors:  53% 1.31G/2.47G [00:30<00:27, 42.3MB/s]
# model.safetensors:  53% 1.32G/2.47G [00:31<00:27, 42.4MB/s]
# model.safetensors:  54% 1.33G/2.47G [00:31<00:26, 42.6MB/s]
# model.safetensors:  54% 1.34G/2.47G [00:31<00:26, 42.5MB/s]
# model.safetensors:  55% 1.35G/2.47G [00:31<00:26, 42.8MB/s]
# model.safetensors:  55% 1.36G/2.47G [00:32<00:25, 43.0MB/s]
# model.safetensors:  56% 1.37G/2.47G [00:32<00:25, 43.0MB/s]
# model.safetensors:  56% 1.38G/2.47G [00:32<00:25, 43.0MB/s]
# model.safetensors:  56% 1.39G/2.47G [00:32<00:25, 42.7MB/s]
# model.safetensors:  57% 1.41G/2.47G [00:33<00:24, 42.7MB/s]
# model.safetensors:  57% 1.42G/2.47G [00:33<00:24, 42.7MB/s]
# model.safetensors:  58% 1.43G/2.47G [00:33<00:24, 42.8MB/s]
# model.safetensors:  58% 1.44G/2.47G [00:33<00:24, 42.9MB/s]
# model.safetensors:  59% 1.45G/2.47G [00:34<00:23, 42.9MB/s]
# model.safetensors:  59% 1.46G/2.47G [00:34<00:23, 42.7MB/s]
# model.safetensors:  59% 1.47G/2.47G [00:34<00:23, 42.7MB/s]
# model.safetensors:  60% 1.48G/2.47G [00:34<00:23, 42.6MB/s]
# model.safetensors:  60% 1.49G/2.47G [00:35<00:23, 42.7MB/s]
# model.safetensors:  61% 1.50G/2.47G [00:35<00:26, 36.1MB/s]
# model.safetensors:  62% 1.52G/2.47G [00:35<00:21, 44.1MB/s]
# model.safetensors:  62% 1.53G/2.47G [00:36<00:21, 43.6MB/s]
# model.safetensors:  62% 1.54G/2.47G [00:36<00:21, 43.4MB/s]
# model.safetensors:  63% 1.55G/2.47G [00:36<00:21, 43.3MB/s]
# model.safetensors:  63% 1.56G/2.47G [00:36<00:21, 42.9MB/s]
# model.safetensors:  64% 1.57G/2.47G [00:37<00:21, 42.7MB/s]
# model.safetensors:  64% 1.58G/2.47G [00:37<00:20, 42.4MB/s]
# model.safetensors:  64% 1.59G/2.47G [00:37<00:20, 42.4MB/s]
# model.safetensors:  65% 1.60G/2.47G [00:37<00:20, 42.3MB/s]
# model.safetensors:  65% 1.61G/2.47G [00:38<00:20, 42.5MB/s]
# model.safetensors:  66% 1.63G/2.47G [00:38<00:19, 42.5MB/s]
# model.safetensors:  66% 1.64G/2.47G [00:38<00:18, 46.1MB/s]
# model.safetensors:  67% 1.65G/2.47G [00:38<00:18, 45.2MB/s]
# model.safetensors:  67% 1.66G/2.47G [00:38<00:18, 44.4MB/s]
# model.safetensors:  67% 1.67G/2.47G [00:39<00:18, 44.1MB/s]
# model.safetensors:  68% 1.68G/2.47G [00:39<00:18, 42.4MB/s]
# model.safetensors:  68% 1.69G/2.47G [00:39<00:18, 42.7MB/s]
# model.safetensors:  69% 1.70G/2.47G [00:39<00:18, 42.7MB/s]
# model.safetensors:  69% 1.71G/2.47G [00:40<00:17, 42.8MB/s]
# model.safetensors:  70% 1.72G/2.47G [00:40<00:18, 41.5MB/s]
# model.safetensors:  70% 1.73G/2.47G [00:40<00:17, 42.1MB/s]
# model.safetensors:  70% 1.74G/2.47G [00:40<00:17, 42.3MB/s]
# model.safetensors:  71% 1.75G/2.47G [00:41<00:17, 42.2MB/s]
# model.safetensors:  71% 1.76G/2.47G [00:41<00:17, 41.4MB/s]
# model.safetensors:  72% 1.77G/2.47G [00:41<00:16, 41.8MB/s]
# model.safetensors:  72% 1.78G/2.47G [00:41<00:16, 42.0MB/s]
# model.safetensors:  73% 1.79G/2.47G [00:42<00:16, 42.2MB/s]
# model.safetensors:  73% 1.80G/2.47G [00:42<00:16, 41.5MB/s]
# model.safetensors:  73% 1.81G/2.47G [00:42<00:15, 42.1MB/s]
# model.safetensors:  74% 1.82G/2.47G [00:42<00:15, 42.2MB/s]
# model.safetensors:  74% 1.84G/2.47G [00:43<00:15, 42.2MB/s]
# model.safetensors:  75% 1.85G/2.47G [00:43<00:15, 41.5MB/s]
# model.safetensors:  75% 1.86G/2.47G [00:43<00:14, 41.6MB/s]
# model.safetensors:  76% 1.87G/2.47G [00:43<00:14, 42.1MB/s]
# model.safetensors:  76% 1.88G/2.47G [00:44<00:14, 42.1MB/s]
# model.safetensors:  76% 1.89G/2.47G [00:44<00:14, 41.6MB/s]
# model.safetensors:  77% 1.90G/2.47G [00:44<00:13, 41.9MB/s]
# model.safetensors:  77% 1.91G/2.47G [00:44<00:13, 42.1MB/s]
# model.safetensors:  78% 1.92G/2.47G [00:45<00:13, 42.4MB/s]
# model.safetensors:  78% 1.93G/2.47G [00:45<00:13, 41.6MB/s]
# model.safetensors:  78% 1.94G/2.47G [00:45<00:12, 42.2MB/s]
# model.safetensors:  79% 1.95G/2.47G [00:45<00:12, 41.8MB/s]
# model.safetensors:  79% 1.96G/2.47G [00:46<00:12, 42.1MB/s]
# model.safetensors:  80% 1.97G/2.47G [00:46<00:12, 41.6MB/s]
# model.safetensors:  80% 1.98G/2.47G [00:46<00:11, 42.0MB/s]
# model.safetensors:  81% 1.99G/2.47G [00:46<00:11, 42.2MB/s]
# model.safetensors:  81% 2.00G/2.47G [00:47<00:11, 42.1MB/s]
# model.safetensors:  81% 2.01G/2.47G [00:47<00:11, 41.5MB/s]
# model.safetensors:  82% 2.02G/2.47G [00:47<00:10, 41.9MB/s]
# model.safetensors:  82% 2.03G/2.47G [00:47<00:10, 42.0MB/s]
# model.safetensors:  83% 2.04G/2.47G [00:48<00:10, 42.5MB/s]
# model.safetensors:  83% 2.06G/2.47G [00:48<00:10, 41.5MB/s]
# model.safetensors:  84% 2.07G/2.47G [00:48<00:09, 42.0MB/s]
# model.safetensors:  84% 2.08G/2.47G [00:48<00:09, 42.2MB/s]
# model.safetensors:  84% 2.09G/2.47G [00:49<00:09, 42.0MB/s]
# model.safetensors:  85% 2.10G/2.47G [00:49<00:09, 41.5MB/s]
# model.safetensors:  85% 2.11G/2.47G [00:49<00:08, 42.2MB/s]
# model.safetensors:  86% 2.12G/2.47G [00:49<00:08, 42.0MB/s]
# model.safetensors:  86% 2.13G/2.47G [00:50<00:08, 42.2MB/s]
# model.safetensors:  87% 2.14G/2.47G [00:50<00:08, 41.5MB/s]
# model.safetensors:  87% 2.15G/2.47G [00:50<00:07, 41.2MB/s]
# model.safetensors:  87% 2.16G/2.47G [00:50<00:07, 41.7MB/s]
# model.safetensors:  88% 2.17G/2.47G [00:51<00:07, 42.0MB/s]
# model.safetensors:  88% 2.18G/2.47G [00:51<00:06, 41.9MB/s]
# model.safetensors:  89% 2.19G/2.47G [00:51<00:06, 41.9MB/s]
# model.safetensors:  89% 2.20G/2.47G [00:51<00:06, 42.1MB/s]
# model.safetensors:  90% 2.21G/2.47G [00:52<00:06, 42.3MB/s]
# model.safetensors:  90% 2.22G/2.47G [00:52<00:05, 41.8MB/s]
# model.safetensors:  90% 2.23G/2.47G [00:52<00:05, 42.3MB/s]
# model.safetensors:  91% 2.24G/2.47G [00:52<00:05, 42.4MB/s]
# model.safetensors:  91% 2.25G/2.47G [00:53<00:05, 42.3MB/s]
# model.safetensors:  92% 2.26G/2.47G [00:53<00:04, 41.5MB/s]
# model.safetensors:  92% 2.28G/2.47G [00:53<00:04, 42.0MB/s]
# model.safetensors:  92% 2.29G/2.47G [00:53<00:04, 42.1MB/s]
# model.safetensors:  93% 2.30G/2.47G [00:54<00:04, 42.1MB/s]
# model.safetensors:  93% 2.31G/2.47G [00:54<00:03, 41.5MB/s]
# model.safetensors:  94% 2.32G/2.47G [00:54<00:03, 42.1MB/s]
# model.safetensors:  94% 2.33G/2.47G [00:54<00:03, 42.1MB/s]
# model.safetensors:  95% 2.34G/2.47G [00:55<00:03, 41.9MB/s]
# model.safetensors:  95% 2.35G/2.47G [00:55<00:02, 41.6MB/s]
# model.safetensors:  95% 2.36G/2.47G [00:55<00:02, 42.0MB/s]
# model.safetensors:  96% 2.37G/2.47G [00:55<00:02, 42.1MB/s]
# model.safetensors:  96% 2.38G/2.47G [00:56<00:02, 42.1MB/s]
# model.safetensors:  97% 2.39G/2.47G [00:56<00:01, 41.5MB/s]
# model.safetensors:  97% 2.40G/2.47G [00:56<00:01, 41.8MB/s]
# model.safetensors:  98% 2.41G/2.47G [00:56<00:01, 42.0MB/s]
# model.safetensors:  98% 2.42G/2.47G [00:57<00:01, 42.1MB/s]
# model.safetensors:  98% 2.43G/2.47G [00:57<00:00, 41.6MB/s]
# model.safetensors:  99% 2.44G/2.47G [00:57<00:00, 42.0MB/s]
# model.safetensors:  99% 2.45G/2.47G [00:57<00:00, 42.2MB/s]
# model.safetensors: 100% 2.46G/2.47G [00:58<00:00, 42.2MB/s]
# model.safetensors: 100% 2.47G/2.47G [00:58<00:00, 42.3MB/s]
# Download complete. Moving file to meta-llama/Llama-3.2-1B-Instruct/model.safetensors
# Fetching 10 files: 100% 10/10 [00:58<00:00,  5.86s/it]
# /content/meta-llama/Llama-3.2-1B-Instruct

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, PeftModel
from trl import SFTTrainer, SFTConfig
import torch

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

# %%
base_model_path = 'meta-llama/Llama-3.2-1B-Instruct'

tokenizer = AutoTokenizer.from_pretrained(base_model_path)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id = tokenizer.eos_token_id

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map='auto',
)

# %%
print(base_model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 2048)
#     (layers): ModuleList(
#       (0-15): 16 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=2048, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear4bit(in_features=2048, out_features=512, bias=False)
#           (v_proj): lora.Linear4bit(
#             (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.05, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=2048, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=512, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=2048, out_features=8192, bias=False)
#           (up_proj): Linear4bit(in_features=2048, out_features=8192, bias=False)
#           (down_proj): Linear4bit(in_features=8192, out_features=2048, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((2048,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=128256, bias=False)
# )

# %%
dataset_hf_path = 'iamtarun/python_code_instructions_18k_alpaca'
dataset = load_dataset(dataset_hf_path)

split_dataset = dataset['train'].train_test_split(test_size=0.25, seed=42)

train_dataset = split_dataset['train']
val_dataset = split_dataset['test']

print(f'Training set size: {len(train_dataset)}')
print(f'Validation set size: {len(val_dataset)}')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Training set size: 13959
# Validation set size: 4653

# %%
print(f'-- data info: {dataset_hf_path} --')
print(f'dataset shape: {train_dataset.shape}')
print(f'dataset columns: {train_dataset.column_names}')
print(f'dataset rows: {train_dataset.num_rows}')
print()
print('-> example fine-tuning prompt:')
print(f"prompt: {train_dataset[0]['prompt']}")
# Out:
# -- data info: iamtarun/python_code_instructions_18k_alpaca --
# dataset shape: (13959, 4)
# dataset columns: ['instruction', 'input', 'output', 'prompt']
# dataset rows: 13959
#
# -> example fine-tuning prompt:
# prompt: Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Develop a Python script to add a given list of numbers.
#
# ### Input:
# [4, 8, 15, 20]
#
# ### Output:
# def sum_list(list_of_nums):
#     total = 0
#     for number in list_of_nums:
#         total += number
#     return total
#
# result = sum_list([4, 8, 15, 20])
# print(result)

# %%
# some notes on input data
# the examples contain test code as well, we onlyr really want the function or piece of code

# %%
def formatting_func(example):
    return example['instruction'] + '\n' + example['output']

# %%
ex1 = formatting_func(train_dataset[0])
ex1
# Out:
# 'Develop a Python script to add a given list of numbers.\ndef sum_list(list_of_nums):\n    total = 0\n    for number in list_of_nums:\n        total += number\n    return total\n\nresult = sum_list([4, 8, 15, 20])\nprint(result)'

# %%
# peft (lora)
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias='none',
    task_type='CAUSAL_LM',
    target_modules=['q_proj', 'v_proj'], # (see model architecture)
    init_lora_weights='gaussian',
)

peft_model = get_peft_model(base_model, lora_config)
peft_model.print_trainable_parameters()
# Out:
# trainable params: 1,703,936 || all params: 1,237,518,336 || trainable%: 0.1377

# %%
training_args = SFTConfig(
    output_dir='./finetuned-llama-3.2-1b-instruct',
    num_train_epochs=2,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    max_seq_length=512,
    max_steps=500,
    save_steps=100,
    label_names=[],
    fp16=True,
    report_to='none',

    logging_steps=10,
    logging_first_step=True,

    lr_scheduler_type='cosine',
    warmup_steps=100,
)

trainer = SFTTrainer(
    model=peft_model,
    args=training_args,

    train_dataset=train_dataset,
    eval_dataset=val_dataset,

    formatting_func=formatting_func,
    processing_class=tokenizer,
)
# Out:
# Tokenizing train dataset:   0%|          | 0/13959 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/13959 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/4653 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/4653 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 00:26, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.812700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.276300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.185100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.165500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.229700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.161600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=50, training_loss=1.214360613822937, metrics={'train_runtime': 27.919, 'train_samples_per_second': 28.654, 'train_steps_per_second': 1.791, 'total_flos': 978727814676480.0, 'train_loss': 1.214360613822937})

# %%
eval_results = trainer.evaluate()
print(eval_results)
# Out:
#     <div>
#
#       <progress value='1164' max='582' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [582/582 03:28]
#     </div>
# {'eval_runtime': 32.8768, 'eval_samples_per_second': 141.528, 'eval_steps_per_second': 17.702}

# %%
output_dir = 'llama-3.2-1b-instruct-ft'

trainer.model.save_pretrained('lora_adapters', save_adapter=True, save_config=True) # save lora adatpers to 'lora_adapters'

model_to_merge = PeftModel.from_pretrained(AutoModelForCausalLM.from_pretrained(base_model_path, device_map='auto'), 'lora_adapters')
merged_model = model_to_merge.merge_and_unload()
merged_model.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# !du -sh llama-3.2-1b-instruct-ft/model.safetensors
# Out:
# 4.7G	llama-3.2-1b-instruct-ft/model.safetensors

# %%
ft_model = AutoModelForCausalLM.from_pretrained(output_dir, device_map='auto')
input_text = 'write a python function to generate the first n fibonacci numbers. exclude any extra comments or examples. just the python function bare bones.'
inputs = tokenizer(input_text, return_tensors='pt').to('cuda')
outputs = ft_model.generate(**inputs, max_new_tokens=250)
print(tokenizer.decode(outputs[0], skip_special_tokens=True)) # TODO: how to prevent from outputing more tokens than needed?
